# %% [markdown]
# # Week 1_HW

# %% [markdown]
# ### Action2 使用python爬取网站投诉信息

# %% [markdown]
# ##### 导入需要的包

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# ##### 设定需要爬取的网页

# %%
base_url = 'http://www.12365auto.com/zlts/0-0-0-0-0-0_0-0-0-0-0-0-0-'

# %% [markdown]
# ##### 以下方法可以根据传进的网页参数得到BS对象
# ##### 参数：网址
# ##### 返回： 网址内容的BS对象

# %%
def get_page_content(request_url):
    # 得到页面的内容
    #加header有请求的信息比如访问网站的编码，设备等
    header={'user-agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.131 Safari/537.36'}
    html=requests.get(request_url,headers=header,timeout=10)
    content = html.text
    #print(content)

    # 通过content创建BeautifulSoup对象
    #常见的coding有utf-8，GBK
    #加from_encoding会有一个user warning，去掉warning就消失，因为python3默认coding为unicode，再设置from_encoding为utf-8会被忽略
    soup = BeautifulSoup(content, 'html.parser')
    return soup

# %% [markdown]
# ##### 以下方法可以根据传进的BS对象得到页面的内容
# ##### 参数：BS 对象
# ##### 返回：想要的DataFrame对象

# %%
def analysis(soup):
    # 通过网页的开发者模式，找到内容对应的tag，发现是<div class = "tslb_b">
    temp = soup.find('div',class_="tslb_b")
    # 创建DataFrame
    df = pd.DataFrame(columns = ['id', 'brand', 'car_model', 'type', 'desc', 'problem', 'datetime', 'status'])
    tr_list = temp.find_all('tr')
    for tr in tr_list:
        # ToDo：提取汽车投诉信息
        temp = {}
        #对于每一行记录，再找到每一列的信息，tag是td
        td_list = tr.find_all('td')
        #第一行是表头
        if len(td_list) > 0:
            temp['id'], temp['brand'], temp['car_model'], temp['type'], temp['desc'], temp['problem'], temp['datetime'], temp['status'] = td_list[0].text, td_list[1].text, td_list[2].text, td_list[3].text,td_list[4].text,td_list[5].text,td_list[6].text,td_list[7].text
            df = df.append(temp,ignore_index = True)

    return df

# %%
page_num = 20

# %%
result = pd.DataFrame(columns = ['id', 'brand', 'car_model', 'type', 'desc', 'problem', 'datetime', 'status'])

# %%
for i in range(page_num):
    request_url = base_url+str(i+1)+'.shtml'
    soup = get_page_content(request_url)
    print(request_url)
    df = analysis(soup)
    print(df)
    result = result.append(df)
# Out:
# http://www.12365auto.com/zlts/0-0-0-0-0-0_0-0-0-0-0-0-0-1.shtml
#         id      brand    car_model                           type  \
# 0   515482       东风标致        标致508              2012款 2.0L 自动 智享版
# 1   515481       一汽解放        解放J6P               2020款质惠2.0 460马力
# 2   515479       东风标致        标致408              2015款 1.2T 自动 豪华版
# 3   515475      长安马自达     马自达CX-30              2020款 2.0L 自动 雅悦型
# 4   515474       东风日产           天籁        2020款 2.0L XL Upper 智行版
# 5   515469       一汽吉林         森雅R7              2017款 1.6L 自动 智能型
# 6   515467       上汽集团          名爵3               2011款 1.3 手动 舒适版
# 7   515465      一汽-大众          高尔夫    2019款 280TSI DSG R-Line型 国V
# 8   515443     上汽通用五菱        宝骏530           2018款 1.5T 手动 豪华型 国V
# 9   515439       一汽丰田       RAV4荣放          2020款 2.0L CVT 两驱 风尚版
# 10  515438       北京越野       北京BJ40  2019款 PLUS 2.3T 手动 四驱 尊贵版 国VI
# 11  515435       上汽大众           朗逸          2019款 1.5L 自动 视野版 国VI
# ...

# %%
result.to_csv('car_complain_result.csv', index=False)
